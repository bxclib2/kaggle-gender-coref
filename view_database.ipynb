# %%
from utils.get_settings import parse
import pandas as pd

settings = parse("./utils")

settings
# Out:
# {'train': {'file_path': 'https://raw.githubusercontent.com/google-research-datasets/gap-coreference/master/gap-test.tsv',
#   'pickle_path': '../temp_result/train_data.pkl',
#   'pickle_path_augument': '../temp_result/train_data_a.pkl'},
#  'test': {'file_path': 'https://raw.githubusercontent.com/google-research-datasets/gap-coreference/master/gap-development.tsv',
#   'pickle_path': '../temp_result/test_data.pkl',
#   'pickle_path_augument': '../temp_result/test_data_a.pkl'},
#  'valid': {'file_path': 'https://raw.githubusercontent.com/google-research-datasets/gap-coreference/master/gap-validation.tsv',
#   'pickle_path': '../temp_result/valid_data.pkl',
#   'pickle_path_augument': '../temp_result/valid_data_a.pkl'}}

# %%
train_data = pd.read_pickle(settings["train"]["pickle_path"][1:])
test_data = pd.read_pickle(settings["test"]["pickle_path"][1:])
valid_data = pd.read_pickle(settings["valid"]["pickle_path"][1:])

# %%
train_data.tail()
# Out:
#              ID                                               Text Pronoun  \
# 1995  test-1996  The sole exception was Wimbledon, where she pl...     She
# 1996  test-1997  According to news reports, both Moore and Fily...     her
# 1997  test-1998  In June 2009, due to the popularity of the Sab...     She
# 1998  test-1999  She was delivered to the Norwegian passenger s...     she
# 1999  test-2000  Meg and Vicky each have three siblings, and ha...     her
#
#       Pronoun-offset                   A  A-offset  A-coref  \
# 1995             479    Goolagong Cawley       400     True
# 1996             338  Esther Sheryl Wood       263     True
# 1997             328               Kayla       364     True
# 1998             305                Irma       255     True
# 1999             275        Vicky Austin       217     True
#
#                        B  B-offset  B-coref  ...  \
# 1995        Peggy Michel       432    False  ...
# 1996      Barbara Morgan       404    False  ...
# 1997  Natasha Henstridge       412    False  ...
# 1998              Bergen       274    False  ...
# 1999       Polly O'Keefe       260    False  ...
#
#                                 B_vector_bert_1024_mean  \
# 1995  [-0.34410498, -0.23151395, 0.4869321, -0.07703...
# 1996  [-0.34959722, 0.15987018, 0.21756673, 0.148476...
# 1997  [-0.16807513, -0.124387555, 0.22357456, 0.3628...
# 1998  [-0.30956715, 0.79081154, 0.31109822, 0.405848...
# 1999  [-0.65313727, 0.0947511, -0.21495889, 0.017656...
#
#                              pron_vector_bert_1024_mean  \
# 1995  [-0.7649605, -0.4366843, 0.38759252, 0.5346223...
# 1996  [-0.14545152, -0.01811517, 0.8394235, -0.93023...
# 1997  [-0.8260292, -0.59548515, 0.04561778, -0.17821...
# 1998  [-0.97279143, 0.2389887, -0.22996032, -0.00321...
# 1999  [-0.56508684, 0.04315004, -0.17839415, -0.3307...
#
#                              product_vector_A_bert_1024  \
# 1995  [0.11406859, 0.03454206, 0.2283183, 0.04782291...
# 1996  [0.06410436, -0.0016351662, 0.12631176, 0.1000...
# 1997  [-0.09484517, -0.080319546, -0.0022544423, -0....
# 1998  [0.75074035, -0.050938085, 0.077419795, -0.000...
# 1999  [0.32946235, 0.0031793315, 0.01654137, 0.07624...
#
#                              product_vector_B_bert_1024  \
# 1995  [0.26322672, 0.10109851, 0.18873124, -0.041186...
# 1996  [0.050849445, -0.0028960756, 0.18263061, -0.13...
# 1997  [0.13883497, 0.074070945, 0.010198976, -0.0646...
# 1998  [0.30114427, 0.18899502, -0.071540244, -0.0013...
# 1999  [0.36907926, 0.0040885136, 0.03834741, -0.0058...
#
#                                  A_vector_bert_256_mean  \
# 1995  [-0.171403, -0.4057482, -0.47666842, -0.270443...
# 1996  [0.56031704, 0.03621099, -0.5594447, 0.0859372...
# 1997  [0.6203897, 0.4300091, 0.30379778, 1.3983557, ...
# 1998  [-0.69979453, -0.44887957, -0.21628278, -0.509...
# 1999  [-0.5419043, -0.036526673, -0.13798435, -0.255...
#
#                                  B_vector_bert_256_mean  \
# 1995  [-0.47419462, 0.5055274, -0.074567735, 0.30300...
# 1996  [-0.5140588, 0.19695783, -0.0828488, 0.2230080...
# 1997  [0.5873137, 0.12510478, 0.081058554, 0.6736881...
# 1998  [-0.81550246, -0.13277012, 0.50108314, -0.4330...
# 1999  [-0.39947483, -0.098152794, 0.25745136, -0.009...
#
#                               pron_vector_bert_256_mean  \
# 1995  [-0.13855383, -0.1971774, 0.37948307, 0.144610...
# 1996  [0.6599262, 0.74836516, -0.17937782, 0.5602119...
# 1997  [0.24391061, -0.6219016, -0.14943314, 0.694560...
# 1998  [-1.2459968, 0.3374083, -0.12519275, -0.435292...
# 1999  [-0.17940697, 0.15530047, 0.05025411, -0.31306...
#
#                               product_vector_A_bert_256  \
# 1995  [0.023748543, 0.08000437, -0.1808876, -0.03910...
# 1996  [0.36976787, 0.027099045, 0.100351974, 0.04814...
# 1997  [0.15131964, -0.26742333, -0.045397457, 0.9712...
# 1998  [0.87194175, -0.1514557, 0.027077036, 0.221742...
# 1999  [0.097221404, -0.0056726094, -0.006934281, 0.0...
#
#                               product_vector_B_bert_256  label
# 1995  [0.06570148, -0.09967857, -0.028297193, 0.0438...      0
# 1996  [-0.33924088, 0.14739637, 0.014861238, 0.12493...      0
# 1997  [0.14325204, -0.07780286, -0.012112834, 0.4679...      0
# 1998  [1.0161135, -0.04479774, -0.062731974, 0.18848...      0
# 1999  [0.07166857, -0.0152431745, 0.012937989, 0.002...      0
#
# [5 rows x 52 columns]

# %%
train_data.columns
# Out:
# Index(['ID', 'Text', 'Pronoun', 'Pronoun-offset', 'A', 'A-offset', 'A-coref',
#        'B', 'B-offset', 'B-coref', 'URL', 'vector_bert_1024', 'bert_tokens',
#        'name_list', 'token_map_bert', 'sentence_map_bert', 'A_dist_bert',
#        'B_dist_bert', 'A_pos_bert', 'B_pos_bert', 'pron_pos_bert',
#        'A_idx_bert', 'B_idx_bert', 'pron_idx_bert', 'A_vector_bert_1024',
#        'B_vector_bert_1024', 'pron_vector_bert_1024', 'topic', 'topic_A',
#        'topic_B', 'vector_bert_256', 'A_vector_bert_256', 'B_vector_bert_256',
#        'pron_vector_bert_256', 'name_idx_bert', 'neither_list',
#        'neither_idx_bert', 'name_vector_bert_1024', 'neither_vector_bert_1024',
#        'name_vector_bert_256', 'neither_vector_bert_256',
#        'A_vector_bert_1024_mean', 'B_vector_bert_1024_mean',
#        'pron_vector_bert_1024_mean', 'product_vector_A_bert_1024',
#        'product_vector_B_bert_1024', 'A_vector_bert_256_mean',
#        'B_vector_bert_256_mean', 'pron_vector_bert_256_mean',
#        'product_vector_A_bert_256', 'product_vector_B_bert_256', 'label'],
#       dtype='object')

# %%
train_data_a = pd.read_pickle(settings["train"]["pickle_path_augument"][1:])
test_data_a = pd.read_pickle(settings["test"]["pickle_path_augument"][1:])
valid_data_a = pd.read_pickle(settings["valid"]["pickle_path_augument"][1:])

# %%
train_data_a.tail()
# Out:
#              ID                                               Text Pronoun  \
# 1440  test-1982  Still sure there was some sort of error in her...     her
# 1441  test-1983  Prince Edward is an important character in Nor...     her
# 1442  test-1984  Cook lives in Oxfordshire with her husband, th...     Her
# 1443  test-1989  Sobered by the diagnosis, Sadie sacrifices her...     she
# 1444  test-1992  She has the distinction of being the first fem...     She
#
#       Pronoun-offset                 A  A-offset  A-coref       B  B-offset  \
# 1440             291             Donna       249    False  Weston        80
# 1441             280       Norah Lofts        43    False  Edward         7
# 1442             330    Megan Macqueen       206    False     Ian        62
# 1443             457             Dolly       367    False   Tommy        70
# 1444             363  Vivian Colobella       264    False  Kandee       247
#
#       B-coref  ...                            B_vector_bert_1024_mean  \
# 1440    False  ...  [-0.282752, 0.44045272, -0.16815029, -0.126975...
# 1441    False  ...  [-0.37290993, 1.098882, 0.049777627, -0.186013...
# 1442    False  ...  [-0.22983211, -0.149786, -0.19198531, 0.549313...
# 1443    False  ...  [-0.76646227, 0.37736088, 0.43795377, 0.415202...
# 1444    False  ...  [-0.751409, 0.43532157, 0.20915435, -0.4139840...
#
#                              pron_vector_bert_1024_mean  \
# 1440  [-0.34913534, 0.2077736, 0.18587857, -0.080315...
# 1441  [-0.43210465, 0.5562654, -0.51887923, -0.29208...
# 1442  [-0.37197685, -0.08051762, -0.25786197, -0.476...
# 1443  [-1.3185914, 0.8088266, -0.21499316, 0.1407138...
# 1444  [-0.74860764, -0.44908255, 1.1458538, -0.47485...
#
#                              product_vector_A_bert_1024  \
# 1440  [0.18407728, 0.11221954, 0.031704463, 0.042853...
# 1441  [0.21747549, -0.10036211, -0.021217879, -0.173...
# 1442  [0.07772554, -0.013079676, 0.0030740618, -0.06...
# 1443  [0.1726877, -0.34794542, -0.018675223, 0.04540...
# 1444  [0.24488813, -0.09391636, 0.43098232, -0.12861...
#
#                              product_vector_B_bert_1024 label  \
# 1440  [0.09871872, 0.091514446, -0.031255536, 0.0101...     2
# 1441  [0.16113612, 0.61127, -0.025828578, 0.05433245...     2
# 1442  [0.08549222, 0.012060412, 0.04950571, -0.26161...     2
# 1443  [1.0106505, 0.30521953, -0.09415707, 0.0584246...     2
# 1444  [0.5625105, -0.19549532, 0.23966031, 0.1965840...     2
#
#                                  A_vector_bert_256_mean  \
# 1440  [-0.049995765, -0.60634166, 0.20255497, 0.6519...
# 1441  [-0.3109052, -0.26638955, 0.18921939, -0.30856...
# 1442  [0.087708816, -0.62591285, 0.05713142, 0.08633...
# 1443  [0.38088372, -0.47499472, -0.23724352, 0.17390...
# 1444  [-0.3937323, -0.091270685, -0.08154824, 0.0990...
#
#                                  B_vector_bert_256_mean  \
# 1440  [0.1495116, -0.34842277, 0.5431875, 0.5604353,...
# 1441  [-0.24005964, -0.36902916, -0.26978564, -0.839...
# 1442  [0.2812255, -0.48392832, -0.048053026, 0.06798...
# 1443  [0.17742214, -0.84216654, 0.5229067, -0.234712...
# 1444  [0.05794612, -0.50453717, 0.7336615, 0.2957242...
#
#                               pron_vector_bert_256_mean  \
# 1440  [0.19477811, -0.13037822, 0.4184101, -0.613263...
# 1441  [-0.2885028, -0.0913441, 0.82021976, 0.0228908...
# 1442  [0.15799408, -0.29900932, 0.36529776, 0.506040...
# 1443  [0.010341406, -0.3127415, 0.66500294, 0.174266...
# 1444  [0.3959269, -0.58405113, -0.43202242, -0.17479...
#
#                               product_vector_A_bert_256  \
# 1440  [-0.009738081, 0.079053745, 0.08475105, -0.399...
# 1441  [0.08969702, 0.024333114, 0.15520148, -0.00706...
# 1442  [0.013857474, 0.18715377, 0.02086998, 0.043686...
# 1443  [0.0039388733, 0.14855056, -0.15776764, 0.0303...
# 1444  [-0.15588921, 0.053306747, 0.035230666, -0.017...
#
#                               product_vector_B_bert_256
# 1440  [0.029121589, 0.045426738, 0.22727513, -0.3436...
# 1441  [0.069257885, 0.03370864, -0.22128351, -0.0192...
# 1442  [0.044431962, 0.14469908, -0.017553663, 0.0344...
# 1443  [0.0018347943, 0.2633804, 0.3477345, -0.040902...
# 1444  [0.022942428, 0.2946755, -0.31695822, -0.05169...
#
# [5 rows x 54 columns]

# %%
train_data_a.columns
# Out:
# Index(['ID', 'Text', 'Pronoun', 'Pronoun-offset', 'A', 'A-offset', 'A-coref',
#        'B', 'B-offset', 'B-coref', 'URL', 'vector_bert_1024', 'bert_tokens',
#        'name_list', 'token_map_bert', 'sentence_map_bert', 'A_dist_bert',
#        'B_dist_bert', 'A_pos_bert', 'B_pos_bert', 'pron_pos_bert',
#        'A_idx_bert', 'B_idx_bert', 'pron_idx_bert', 'A_vector_bert_1024',
#        'B_vector_bert_1024', 'pron_vector_bert_1024', 'topic', 'topic_A',
#        'topic_B', 'vector_bert_256', 'A_vector_bert_256', 'B_vector_bert_256',
#        'pron_vector_bert_256', 'neither_name', 'len', 'name_idx_bert',
#        'neither_list', 'neither_idx_bert', 'name_vector_bert_1024',
#        'neither_vector_bert_1024', 'name_vector_bert_256',
#        'neither_vector_bert_256', 'A_vector_bert_1024_mean',
#        'B_vector_bert_1024_mean', 'pron_vector_bert_1024_mean',
#        'product_vector_A_bert_1024', 'product_vector_B_bert_1024', 'label',
#        'A_vector_bert_256_mean', 'B_vector_bert_256_mean',
#        'pron_vector_bert_256_mean', 'product_vector_A_bert_256',
#        'product_vector_B_bert_256'],
#       dtype='object')

# %%
train_data_a.count()
# Out:
# ID                            1445
# Text                          1445
# Pronoun                       1445
# Pronoun-offset                1445
# A                             1445
# A-offset                      1445
# A-coref                       1445
# B                             1445
# B-offset                      1445
# B-coref                       1445
# URL                           1445
# vector_bert_1024              1445
# bert_tokens                   1445
# token_map_bert                1445
# sentence_map_bert             1445
# A_dist_bert                   1445
# B_dist_bert                   1445
# A_pos_bert                    1445
# B_pos_bert                    1445
# pron_pos_bert                 1445
# A_idx_bert                    1445
# B_idx_bert                    1445
# pron_idx_bert                 1445
# A_vector_bert_1024            1445
# B_vector_bert_1024            1445
# pron_vector_bert_1024         1445
# topic                         1445
# topic_A                       1445
# topic_B                       1445
# name_list                     1445
# name_idx_bert                 1445
# neither_list                  1445
# neither_idx_bert              1445
# name_vector_bert_1024         1445
# neither_vector_bert_1024      1445
# A_vector_bert_1024_mean       1445
# B_vector_bert_1024_mean       1445
# pron_vector_bert_1024_mean    1445
# product_vector_A_bert_1024    1445
# product_vector_B_bert_1024    1445
# label                         1445
# neither_name                  1445
# len                           1445
# dtype: int64
